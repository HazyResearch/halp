# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../utils/")
# from res_processing_utils import get_ave_metric, running_mean
from res_processing_utils import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
pattern = "opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_"
train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
test_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_loss")
test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
grad_norm = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")

# %%
train_loss.shape, test_loss.shape, test_acc.shape, grad_norm.shape
# Out:
# ((39100,), (100,), (100,), (39100,))

# %%
train_loss[-1], test_loss[-1], test_acc[-1], grad_norm[-1]
# Out:
# (0.2675636311372121, 1.4958689574400583, 0.6204333333333333, 4.820598008616545)

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.3137069344520569 grad_norm: 5.4768581387959685 acc: 0.9
# INFO:root:Test metric acc: 0.6108 loss: 1.5290843850374223

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.20535025000572205 grad_norm: 3.684142511069177 acc: 0.9375
# INFO:root:Test metric acc: 0.6391 loss: 1.3510784006118775

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.2836337089538574 grad_norm: 5.300793375984492 acc: 0.9
# INFO:root:Test metric acc: 0.6114 loss: 1.6074440866708755

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["momentum_0.9", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-svrg']
# /dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13//opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_seed_3/run.log has 0 test accuracy record
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.5651961263020894
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 0.7948763020836487
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ nan
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 1.4039908854166787
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.7107177734374818
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1.3586946614587214
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.5643725585934589
# best train loss and config  0.5643725585934589 37122 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_bc-svrg']
# best test acc and config  0.6312333333333333 54 opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
# opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.6906770833332848
# opt_bc-svrg_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 1.6066601562494178
# opt_bc-svrg_momentum_0.0_lr_0.001_l2_reg_0.0005_ 1.3477962239581394
# opt_bc-svrg_momentum_0.0_lr_0.5_l2_reg_0.0005_ nan
# opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.5721582031252183
# opt_bc-svrg_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.8002555338543607
# opt_bc-svrg_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.3039583333331395
# opt_bc-svrg_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.8083007812500181
# best train loss and config  0.5721582031252183 38227 opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_lp-svrg']
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.28288411458328483
# opt_lp-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 2.2486621093749988
# opt_lp-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 1.5564648437495634
# opt_lp-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.8389713541668606
# opt_lp-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 0.980997721354106
# opt_lp-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 2.304036458333176
# opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ nan
# opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.2059096272786337
# best train loss and config  0.2059096272786337 38706 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_lp-svrg']
# best test acc and config  0.6264333333333334 54 opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
# opt_lp-svrg_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 2.3044466145832847
# opt_lp-svrg_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.3045898437499637
# opt_lp-svrg_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.8611409505203482
# opt_lp-svrg_momentum_0.0_lr_0.001_l2_reg_0.0005_ 2.303997395833394
# opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.3119995117188228
# opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_0.0005_ nan
# opt_lp-svrg_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.4769189453125
# opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.4512573242189683
# best train loss and config  0.3119995117188228 38629 opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_svrg']
# best test acc and config  0.6448666666666667 51 opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# opt_svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 0.967402839263159
# opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.45113767087459566
# opt_svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1.6372936065991963
# opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.22132673427451663
# opt_svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ nan
# opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.2832155079145741
# opt_svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 0.7069688585401309
# opt_svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1.3000029607617762
# best train loss and config  0.22132673427451663 37152 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_svrg']
# best test acc and config  0.6339666666666667 75 opt_svrg_momentum_0.0_lr_0.005_l2_reg_0.0005_
# opt_svrg_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.3714532121022421
# opt_svrg_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.259257716337452
# opt_svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.33837946320592893
# opt_svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.41221204767651215
# opt_svrg_momentum_0.0_lr_0.001_l2_reg_0.0005_ 1.2991501275696646
# opt_svrg_momentum_0.0_lr_0.5_l2_reg_0.0005_ 1.583231561188586
# opt_svrg_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 1.561646375258715
# opt_svrg_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.7166167312859034
# best train loss and config  0.33837946320592893 34734 opt_svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_

# %%
pattern_list = ["momentum_0.9", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-sgd']
# best test acc and config  0.6385 99 opt_bc-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# opt_bc-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.6296370442706393
# opt_bc-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 0.8230615234378638
# opt_bc-sgd_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1.3533300781251456
# opt_bc-sgd_momentum_0.9_lr_0.05_l2_reg_0.0005_ 1.3782486979166833
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# opt_bc-sgd_momentum_0.9_lr_0.5_l2_reg_0.0005_ nan
# opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.7101074218751819
# opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.8834195963540878
# opt_bc-sgd_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1.7813704427083348
# best train loss and config  0.6296370442706393 38856 opt_bc-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_bc-sgd']
# best test acc and config  0.6374666666666666 57 opt_bc-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_
# opt_bc-sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.864466145833394
# opt_bc-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.57043701171875
# opt_bc-sgd_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.8284000651044334
# opt_bc-sgd_momentum_0.0_lr_0.5_l2_reg_0.0005_ nan
# opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.647862955729106
# opt_bc-sgd_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.3000325520834304
# opt_bc-sgd_momentum_0.0_lr_0.001_l2_reg_0.0005_ 1.3613313802081393
# opt_bc-sgd_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 1.6097526041670063
# best train loss and config  0.57043701171875 38647 opt_bc-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_lp-sgd']
# best test acc and config  0.6387666666666667 64 opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.240480346679833
# opt_lp-sgd_momentum_0.9_lr_0.5_l2_reg_0.0005_ 2.2662565104166696
# opt_lp-sgd_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1.3469856770834303
# opt_lp-sgd_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 2.302962239583576
# opt_lp-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 0.8770882161457848
# opt_lp-sgd_momentum_0.9_lr_0.05_l2_reg_0.0005_ 0.8452425130206394
# opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.3311547851564319
# opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.5292252604164969
# best train loss and config  0.240480346679833 37918 opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_lp-sgd']
# best test acc and config  0.6373 99 opt_lp-sgd_momentum_0.0_lr_0.005_l2_reg_0.0005_
# opt_lp-sgd_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 2.3017578125001457
# opt_lp-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.4482869466148259
# opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.17786671956382633
# opt_lp-sgd_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.7763655598953483
# opt_lp-sgd_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.3044205729168605
# opt_lp-sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.3414672851562136
# opt_lp-sgd_momentum_0.0_lr_0.5_l2_reg_0.0005_ nan
# opt_lp-sgd_momentum_0.0_lr_0.001_l2_reg_0.0005_ 2.2766080729162788
# best train loss and config  0.17786671956382633 38664 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_sgd']
# best test acc and config  0.6393666666666666 99 opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 0.744425496757176
# opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_ 0.340405309001726
# opt_sgd_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1.312112885316892
# opt_sgd_momentum_0.9_lr_0.05_l2_reg_0.0005_ 0.8421339267494478
# opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_ 0.23107699560601758
# opt_sgd_momentum_0.9_lr_0.5_l2_reg_0.0005_ 2.309745550950361
# opt_sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_ 0.47718859970547783
# opt_sgd_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1.3704708524544549
# best train loss and config  0.23107699560601758 38314 opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_sgd']
# best test acc and config  0.6316999999999999 54 opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_
# opt_sgd_momentum_0.0_lr_0.0001_l2_reg_0.0005_ 2.2592878516513157
# opt_sgd_momentum_0.0_lr_0.001_l2_reg_0.0005_ 1.312907602389605
# opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_ 0.43142075389579987
# opt_sgd_momentum_0.0_lr_0.005_l2_reg_0.0005_ 0.752189748684541
# opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_ 0.19652491370816277
# opt_sgd_momentum_0.0_lr_0.0005_l2_reg_0.0005_ 1.5652764153479075
# opt_sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_ 0.34123746563975144
# opt_sgd_momentum_0.0_lr_0.5_l2_reg_0.0005_ nan
# best train loss and config  0.19652491370816277 37057 opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_

# %% [markdown]
# # plot each specific results according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_" + mom + "_lr_0.01_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_" + mom + "_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_" + mom + "_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_" + mom + "_lr_0.01_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_" + mom + "_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %% [markdown]
# # plot by the best sgd setting according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %% [markdown]
# # plot each specific results according to train loss

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %% [markdown]
# # plot by the best sgd setting

# %%
# top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
# all_directories = get_immediate_subdirectories(top_directory)
# all_directories = get_subdirectories_patterns_without_seed(all_directories)

# pattern_list = ["momentum_0.9", "_bc-svrg", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_bc-svrg", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.9", "_lp-svrg", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_lp-svrg", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.9", "_svrg", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_svrg", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# %%
# pattern_list = ["momentum_0.9", "_bc-sgd", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_bc-sgd", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.9", "_lp-sgd", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_lp-sgd", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.9", "_sgd", "_lr_0.005"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# pattern_list = ["momentum_0.0", "_sgd", "_lr_0.05"]
# print("\n")
# print(pattern_list)
# dir_list = filter_directory_names(all_directories, pattern_list)
# get_config_with_best_test_acc(top_directory, dir_list)

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %%
from res_processing_utils import *

# %%
def get_config_with_best_train_loss(top_directory, pattern_list, seed_list=[1, 2, 3]):
        best_train_loss = np.finfo(dtype=np.float64).max
        best_config = ""
        best_loss_epoch_id = 0
        for pattern in pattern_list:
                ave_loss = None
                try:
                    for seed in seed_list:
                            print(pattern, seed)
                            dir = pattern + "seed_" + str(seed)
                            if not os.path.exists(top_directory + "/" + dir + "/run.log"):
                                    print(top_directory + "/" + dir + "/run.log missing!" )
                                    continue
                            loss = get_train_loss(top_directory + "/" + dir + "/run.log")
                            if len(loss) == 0:
                                    print(top_directory + "/" + dir + "/run.log has 0 train loss record" )
                                    continue
                            if ave_loss is None:
                                     ave_loss = np.array(loss)
                            else:
                                     ave_loss += np.array(loss)
                    ave_loss /= len(seed_list)
                    ave_loss = running_mean(ave_loss, N=1000)
                        
                    print(np.min(ave_loss))
                    
                    if np.min(ave_loss) <  best_train_loss:
                            best_train_loss = np.min(ave_loss)
                            best_config = pattern
                            best_loss_epoch_id = np.argmin(ave_loss)
                except:
                        continue
        print("best train loss and config ", best_train_loss, best_loss_epoch_id, best_config)

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["momentum_0.9", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-svrg']
# /dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13//opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_seed_3/run.log has 0 test accuracy record
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 3
# 1.4589212239583351
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 3
# 1.3799029947915697
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 3
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 3
# 0.8122133789062136
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 3
# 0.5985524902343805
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 3
# 0.7517674153645713
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 3
# 0.5838754882812209
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 3
# nan
# best train loss and config  0.5838754882812209 36577 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

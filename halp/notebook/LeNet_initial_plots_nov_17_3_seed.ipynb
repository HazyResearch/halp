# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../utils/")
# from res_processing_utils import get_ave_metric, running_mean
from res_processing_utils import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
pattern = "opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_"
train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
test_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_loss")
test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
grad_norm = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")

# %%
train_loss.shape, test_loss.shape, test_acc.shape, grad_norm.shape
# Out:
# ((39100,), (100,), (100,), (39100,))

# %%
train_loss[-1], test_loss[-1], test_acc[-1], grad_norm[-1]
# Out:
# (0.335358683069547, 1.563664009372393, 0.6204333333333333, 4.820502323173415)

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.3137069344520569 grad_norm: 5.4768581387959685 acc: 0.9
# INFO:root:Test metric acc: 0.6108 loss: 1.5290843850374223

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.20535025000572205 grad_norm: 3.684142511069177 acc: 0.9375
# INFO:root:Test metric acc: 0.6391 loss: 1.3510784006118775

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.2836337089538574 grad_norm: 5.300793375984492 acc: 0.9
# INFO:root:Test metric acc: 0.6114 loss: 1.6074440866708755

# %% [markdown]
# ## overall report

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['_bc-svrg']
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# best train loss and config  0.42217592675397464 37153 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_lp-svrg']
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.43630979612196824 37930 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_svrg']
# best test acc and config  0.6448666666666667 51 opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4371521732883266 28166 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_

# %%
pattern_list = ["_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)


pattern_list = ["_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['_bc-sgd']
# best test acc and config  0.6385 99 opt_bc-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# best train loss and config  0.44933042728525835 38100 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_lp-sgd']
# best test acc and config  0.6387666666666667 64 opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4403634448743978 37954 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_sgd']
# best test acc and config  0.6393666666666666 99 opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# best train loss and config  0.450467172505756 36353 opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_

# %% [markdown]
# ### momentum specific

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["momentum_0.9", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-svrg']
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# best train loss and config  0.42217592675397464 37153 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_bc-svrg']
# best test acc and config  0.6312333333333333 54 opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.5279477668869076 38100 opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_lp-svrg']
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.43630979612196824 37930 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_lp-svrg']
# ...

# %%
pattern_list = ["momentum_0.9", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-sgd']
# best test acc and config  0.6385 99 opt_bc-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# best train loss and config  0.49792108646239647 37866 opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_bc-sgd']
# best test acc and config  0.6374666666666666 57 opt_bc-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.44933042728525835 38100 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['momentum_0.9', '_lp-sgd']
# best test acc and config  0.6387666666666667 64 opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4998482413944439 36539 opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['momentum_0.0', '_lp-sgd']
# ...

# %% [markdown]
# # plot each specific results according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %% [markdown]
# # plot by the best sgd setting according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()

# %% [markdown]
# # plot each specific results according to train loss

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
    
#     plt.figure()
#     for pattern, label in zip(pattern_list, label_list):
#         print(pattern)
# #         if "_bc-svrg" in pattern:
# #             continue
#         train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")
#         train_loss = running_mean(train_loss, N=1000)
#         print(label, train_loss[:20], train_loss[-20:])
        
        
#         plt.semilogy(train_loss, label=label)
#     plt.legend()
#     # plt.ylim([0.55, None])
#     plt.xlabel("iters")
#     plt.ylabel("grad_norm")
#     plt.title("grad norm")
#     plt.grid()
#     plt.show()
# Out:
# opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# sgd [2.02487717 2.02671926 2.02852286 2.03009409 2.03200982 2.03380565
#  2.03542572 2.03692012 2.03896106 2.04110285 2.04400133 2.04620735
#  2.04836785 2.05023658 2.052069   2.05403769 2.05639933 2.05978264
#  2.06289746 2.06547764] [4.76438179 4.76283813 4.76161116 4.76243625 4.76305351 4.76418246
#  4.76406947 4.76211974 4.76179468 4.76105644 4.76049819 4.76105518
#  4.76123249 4.76192    4.76406433 4.76653756 4.76825419 4.76931846
#  4.76971349 4.77060814]
# opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# lp-sgd [2.0254207  2.02726604 2.02910602 2.03067992 2.03262375 2.03438952
#  2.03596987 2.03740256 2.03939708 2.04147808 2.04435335 2.04661474
#  2.04888326 2.05076305 2.05253809 2.05464625 2.05716345 2.0605501
#  2.06356855 2.06609179] [4.60544256 4.60447376 4.60467693 4.60527536 4.60601676 4.60587622
#  4.60574228 4.60538979 4.60532789 4.60593943 4.60512164 4.60632588
# ...

# %% [markdown]
# # plot by the best sgd setting

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_",
                       "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_"]
    label_list = ["sgd", "lp-sgd", "bc-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.35, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.plot(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_loss")
#         test_loss = running_mean(train_loss, N=1000)
        plt.plot(test_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("test loss")
    plt.title("test loss mom " + mom)
    plt.grid()
    plt.show()

# %%
file_names = ["opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log",
             "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_2/run.log",
             "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_3/run.log",
             "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log",
             "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_2/run.log",
             "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_3/run.log"]
for i, file_name in enumerate(file_names):
    print(i)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = ["void_opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log",
             "stoc_opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log",
             "opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log",
             "opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log", 
             "from_dawn_opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_seed_1/run.log"]
label = ["void", "stoc", "near", "lp"]
for i, file_name in enumerate(file_names):
    print(i)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = ["void_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(i)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
# Out:
# 0
# 1

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = ["no_norm_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "no_norm_void_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "near_no_norm_void_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=label)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
# Out:
# no_norm_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log
# no_norm_void_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log
# near_no_norm_void_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = ["near_no_norm_void_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "no_norm_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
# Out:
# near_no_norm_void_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log
# no_norm_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log

# %% [markdown]
# ### retest

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = [#"new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             #"new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
    
    test_acc = get_test_acc(top_directory + "/" + file_name)
    plt.plot(test_acc, label=file_name)
    plt.legend()
    plt.ylim([0.35, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc")
    plt.grid()
    plt.show()
# Out:
# new_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log
# new_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = [#"new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             #"new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log",
             "new_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
    
    test_acc = get_test_acc(top_directory + "/" + file_name)
    plt.plot(test_acc, label=file_name)
    plt.legend()
    plt.ylim([0.35, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc")
    plt.grid()
    plt.show()
# Out:
# new_opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log
# new_opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = [#"new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             #"new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
    
    test_acc = get_test_acc(top_directory + "/" + file_name)
    plt.plot(test_acc, label=file_name)
    plt.legend()
    plt.ylim([0.35, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc")
    plt.grid()
    plt.show()
# Out:
# new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log
# new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_debugging/"
file_names = [#"new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             #"new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0005_seed_1/run.log",
             "new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log",
             "new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log"]
for i, file_name in enumerate(file_names):
    print(file_name)
    train_loss = get_train_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(train_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    plt.figure()
    plt.plot(running_mean(train_loss, N=1000), label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("training loss")
    plt.grid()
    plt.show()
    
    test_loss = get_test_loss(top_directory + "/" + file_name)
    plt.figure()
    plt.plot(test_loss, label=file_name)
    plt.legend()
    plt.xlabel("iters")
    plt.ylabel([0.3, 1.6])
    plt.ylabel("test loss")
    plt.grid()
    plt.show()
    
    test_acc = get_test_acc(top_directory + "/" + file_name)
    plt.plot(test_acc, label=file_name)
    plt.legend()
    plt.ylim([0.35, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc")
    plt.grid()
    plt.show()
# Out:
# new_opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log
# new_opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_0.0_seed_1/run.log

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../utils/")
# from res_processing_utils import get_ave_metric, running_mean
from res_processing_utils import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from plot_utils import save_csv, save_csv_only_y
from plot_utils import get_config_with_best_train_loss, get_config_with_best_test_acc
from plot_utils import plot_test_acc, plot_train_loss
from plot_utils import plot_best_config_multiple_epochs
from plot_utils import plot_best_config_fixed_epochs, plot_best_config_fixed_epochs

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/resnet_weight_loading_fine_tune_dec_7/"
pattern = "opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_"
train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,], metric="train_loss")
test_loss = get_ave_metric(pattern, top_directory, seed_list=[1,], metric="test_loss")
test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,], metric="test_acc")
grad_norm = get_ave_metric(pattern, top_directory, seed_list=[1,], metric="grad_norm")

# %%
train_loss.shape, test_loss.shape, test_acc.shape, grad_norm.shape
# Out:
# ((39100,), (100,), (100,), (39100,))

# %%
train_loss[-1], test_loss[-1], test_acc[-1], grad_norm[-1]
# Out:
# (0.014391094068065286, 0.4467789327763021, 0.8754, 0.004902462424439057)

# %%
def plot_best_config_fixed_epochs(cut_off_epoch=100, total_epoch=100, 
                                  win_width=1000, 
                                  top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/", 
                                  epoch_len=391,
                                  seed_list=[1, 2, 3], 
                                  pattern_list_array=[ ["_bc-svrg",], 
                                                      ["_lp-svrg",],
                                                      ["_svrg",],
                                                      ["_bc-sgd",],
                                                      ["_lp-sgd",],
                                                      ["_sgd",]],
                                  plot_label_list=["halp", "svrg (16)", "svrg (32)", "bc-sgd (16)", "sgd (16)", "sgd (32)"]):
    all_directories = get_immediate_subdirectories(top_directory)
    all_directories = get_subdirectories_patterns_without_seed(all_directories)

    best_train_loss_list = []
    best_test_acc_list = []
    best_train_loss_config_list = []
    best_test_acc_config_list = []
    for pattern_list in pattern_list_array:
        print("\n")
        print(pattern_list)
        dir_list = filter_directory_names(all_directories, pattern_list)
        res = get_config_with_best_test_acc(top_directory, dir_list, cut_off_epoch=cut_off_epoch, total_epoch=total_epoch, seed_list=seed_list)
        best_test_acc_list.append(res[0])
        best_test_acc_config_list.append(res[1])
        res = get_config_with_best_train_loss(top_directory, dir_list, win_width=win_width, cut_off_epoch=cut_off_epoch, total_epoch=total_epoch, epoch_len=epoch_len, seed_list=seed_list)
        best_train_loss_list.append(res[0])
        best_train_loss_config_list.append(res[1])

    plot_test_acc(pattern_list_array, best_test_acc_list)
    plot_train_loss(pattern_list_array, best_train_loss_list)
    return best_test_acc_list, best_train_loss_list, plot_label_list

# %% [markdown]
# ## overall report

# %%
best_test_acc_list, best_train_loss_list, plot_label_list = \
plot_best_config_fixed_epochs(top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/resnet_weight_loading_fine_tune_dec_7/",
                              cut_off_epoch=100, 
                              total_epoch=100, 
                              win_width=1000, 
                              epoch_len=391,
                             seed_list=[1],
                             pattern_list_array=[ ["_bc-svrg", "reg_0.0005"], 
                                                      ["_lp-svrg", "reg_0.0005"],
                                                      ["_svrg", "reg_0.0005"],
                                                      ["_bc-sgd", "reg_0.0005"],
                                                      ["_lp-sgd", "reg_0.0005"],
                                                      ["_sgd", "reg_0.0005"]])
# Out:
# ['_bc-svrg', 'reg_0.0005']
# best test acc and config  0.8759 16 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.014639440565735644 38 opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_
#
#
# ['_lp-svrg', 'reg_0.0005']
# best test acc and config  0.8759 0 opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_
# best train loss and config  0.015502090178659932 29 opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_
#
#
# ['_svrg', 'reg_0.0005']
# best test acc and config  0.8757 22 opt_svrg_momentum_0.0_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.014640510230474628 40 opt_svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_
#
#
# ['_bc-sgd', 'reg_0.0005']
# best test acc and config  0.8762 72 opt_bc-sgd_momentum_0.9_lr_0.0001_l2_reg_0.0005_
# best train loss and config  0.0146489907854482 99 opt_bc-sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_
#
#
# ['_lp-sgd', 'reg_0.0005']
# best test acc and config  0.876 10 opt_lp-sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_
# best train loss and config  0.0147310006698871 13 opt_lp-sgd_momentum_0.9_lr_0.1_l2_reg_0.0005_
#
#
# ['_sgd', 'reg_0.0005']
# best test acc and config  0.8758 20 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.014647327952434386 99 opt_sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_

# %%
best_test_acc_list, best_train_loss_list, plot_label_list = \
plot_best_config_fixed_epochs(top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/resnet_weight_loading_fine_tune_dec_7/",
                              cut_off_epoch=100, 
                              total_epoch=100, 
                              win_width=1000, 
                              epoch_len=391,
                             seed_list=[1],
                             pattern_list_array=[ ["_bc-svrg", ], 
                                                      ["_lp-svrg", ],
                                                      ["_svrg", ],
                                                      ["_bc-sgd", ],
                                                      ["_lp-sgd", ],
                                                      ["_sgd", ]])
# Out:
# ['_bc-svrg']
# best test acc and config  0.8761 26 opt_bc-svrg_momentum_0.0_lr_0.1_l2_reg_0.0_
# best train loss and config  9.455247913175227e-05 99 opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0_
#
#
# ['_lp-svrg']
# best test acc and config  0.8759 0 opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_
# best train loss and config  0.0020428600213716706 16 opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_0.0_
#
#
# ['_svrg']
# best test acc and config  0.8761 28 opt_svrg_momentum_0.9_lr_0.01_l2_reg_1e-06_
# best train loss and config  8.438606853866319e-05 99 opt_svrg_momentum_0.9_lr_0.1_l2_reg_0.0_
#
#
# ['_bc-sgd']
# best test acc and config  0.8762 57 opt_bc-sgd_momentum_0.9_lr_0.0001_l2_reg_0.001_
# best train loss and config  9.366969013458018e-05 99 opt_bc-sgd_momentum_0.9_lr_0.1_l2_reg_0.0_
#
#
# ['_lp-sgd']
# best test acc and config  0.8763 13 opt_lp-sgd_momentum_0.9_lr_0.1_l2_reg_1e-06_
# best train loss and config  0.0009404753175233027 99 opt_lp-sgd_momentum_0.9_lr_0.1_l2_reg_0.0_
#
#
# ['_sgd']
# best test acc and config  0.8761 28 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0_
# best train loss and config  8.451375167176295e-05 99 opt_sgd_momentum_0.9_lr_0.1_l2_reg_0.0_

# %%
save_list = ["halp", "svrg (16)", "svrg (32)", "sgd (16)", "sgd (32)"]

# %%
data_list = [(name, np.arange(y.size) + 1, np.maximum.accumulate(y)) \
             for name, y in zip(plot_label_list, best_test_acc_list) \
            if name in save_list ]
save_csv_only_y(data_list, 
         file_name="./data/lenet_test_acc_all.csv")
data_list = [(name, np.arange(y.size) + 1, y) \
             for name, y in zip(plot_label_list, best_train_loss_list) \
             if name in save_list ]
save_csv_only_y(data_list, 
         file_name="./data/lenet_train_loss_all.csv")

# %%
# ckpt_epochs = np.arange(10, 101, 30)
ckpt_epochs = np.array([3, 5, 10, 15, 20, 30, 50, 100])
_, best_train_loss_list, best_test_acc_list = \
plot_best_config_multiple_epochs(ckpt_epochs, total_epoch=100, 
                               win_width=1000, 
                               top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_17/", 
                               epoch_len=391)
# Out:
# ['_bc-svrg'] 3
# best test acc and config  0.5962999999999999 2 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# best train loss and config  1.180435325681744 2 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 5
# best test acc and config  0.6233 4 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.9931002778278859 4 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 10
# best test acc and config  0.6428666666666667 9 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.8049554291262093 9 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 15
# best test acc and config  0.6440333333333333 13 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.7131202247954798 14 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 20
# best test acc and config  0.6440333333333333 13 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.660800770260006 17 opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 30
# best test acc and config  0.6440333333333333 13 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.5721819782938494 29 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 50
# best test acc and config  0.6440333333333333 13 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.4635106560484985 47 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_bc-svrg'] 100
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4067752794239477 97 opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 3
# best test acc and config  0.5979333333333333 2 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.1791100868352065 2 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 5
# best test acc and config  0.6172 4 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.0044140766513836 4 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 10
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.798171609077498 9 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 15
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.7169706902122864 14 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 20
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.6701897655684319 19 opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 30
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.5785001947977354 29 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 50
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.4799169591814661 48 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_lp-svrg'] 100
# best test acc and config  0.6415333333333333 9 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.4246038773120822 98 opt_lp-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_svrg'] 3
# best test acc and config  0.5899666666666666 2 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.1781514387459566 2 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_svrg'] 5
# best test acc and config  0.6291000000000001 4 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.9900305887156334 4 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_svrg'] 10
# best test acc and config  0.6387999999999999 9 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.812378771550985 9 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_svrg'] 15
# best test acc and config  0.6448 10 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.7074740400813196 14 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_svrg'] 20
# best test acc and config  0.6448 10 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.6803226126460364 19 opt_svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_svrg'] 30
# best test acc and config  0.6448 10 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.5663388687148119 29 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_svrg'] 50
# best test acc and config  0.6448 10 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.4761747897940117 48 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_svrg'] 100
# best test acc and config  0.6448666666666667 51 opt_svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4347313642079822 73 opt_svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 3
# best test acc and config  0.5572 2 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.2972706502787419 2 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 5
# best test acc and config  0.6037333333333333 4 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.1304207467318712 4 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 10
# best test acc and config  0.6141 9 opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.9374401986196396 9 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 15
# best test acc and config  0.6178 14 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# best train loss and config  0.8633068692940655 14 opt_bc-sgd_momentum_0.0_lr_0.1_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 20
# best test acc and config  0.6230333333333334 19 opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.7874175815584308 19 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 30
# best test acc and config  0.6230333333333334 19 opt_bc-sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.6461052430793198 29 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 50
# best test acc and config  0.6358 49 opt_bc-sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.5224232926241679 49 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_bc-sgd'] 100
# best test acc and config  0.6385 99 opt_bc-sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# best train loss and config  0.4474799737800468 98 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 3
# best test acc and config  0.5645333333333333 2 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.3005415771041489 2 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 5
# best test acc and config  0.6055666666666667 4 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.1342183196026407 4 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 10
# best test acc and config  0.6121666666666666 7 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.9394482978422827 9 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 15
# best test acc and config  0.6205333333333334 11 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# best train loss and config  0.861727767928482 14 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 20
# best test acc and config  0.6251 15 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# best train loss and config  0.791324901688066 19 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 30
# best test acc and config  0.6251 15 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
# best train loss and config  0.6541028003445416 29 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 50
# best test acc and config  0.6330333333333334 49 opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.5161034871382736 49 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_lp-sgd'] 100
# best test acc and config  0.6387666666666667 64 opt_lp-sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.4339855224548601 99 opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_sgd'] 3
# best test acc and config  0.5591333333333334 2 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.2968622269734058 2 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_sgd'] 5
# best test acc and config  0.6016666666666667 4 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  1.1324208891557535 4 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_sgd'] 10
# best test acc and config  0.6159666666666667 6 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
# best train loss and config  0.9386085863307257 9 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_sgd'] 15
# best test acc and config  0.6169666666666667 10 opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.8534603733998635 14 opt_sgd_momentum_0.9_lr_0.01_l2_reg_0.0005_
#
#
# ['_sgd'] 20
# best test acc and config  0.6248333333333334 18 opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.7856079919301641 19 opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
#
#
# ['_sgd'] 30
# best test acc and config  0.6248333333333334 18 opt_sgd_momentum_0.9_lr_0.005_l2_reg_0.0005_
# best train loss and config  0.6544884965676887 29 opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_sgd'] 50
# best test acc and config  0.6357333333333334 48 opt_sgd_momentum_0.9_lr_0.001_l2_reg_0.0005_
# best train loss and config  0.5308441784628568 48 opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_
#
#
# ['_sgd'] 100
# best test acc and config  0.6393666666666666 99 opt_sgd_momentum_0.9_lr_0.0005_l2_reg_0.0005_
# best train loss and config  0.44486298534271557 94 opt_sgd_momentum_0.0_lr_0.05_l2_reg_0.0005_

# %%
data_list = [(name, ckpt_epochs, np.maximum.accumulate(y)) \
             for name, y in zip(plot_label_list, best_test_acc_list) \
            if name in save_list ]
save_csv_only_y(data_list, 
         file_name="./data/lenet_test_acc_all_temporal.csv")
data_list = [(name, ckpt_epochs, y) \
             for name, y in zip(plot_label_list, best_train_loss_list) \
            if name in save_list ]
save_csv_only_y(data_list, 
         file_name="./data/lenet_train_loss_all_temporal.csv")

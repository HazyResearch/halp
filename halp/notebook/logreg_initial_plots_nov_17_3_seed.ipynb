# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../utils/")
# from res_processing_utils import get_ave_metric, running_mean
from res_processing_utils import *
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
pattern = "opt_sgd_momentum_0.0_lr_0.01_l2_reg_0.0005_"
train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
test_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_loss")
test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
grad_norm = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")

# %%
train_loss.shape, test_loss.shape, test_acc.shape, grad_norm.shape
# Out:
# ((60000,), (100,), (100,), (60000,))

# %%
train_loss[-1], test_loss[-1], test_acc[-1], grad_norm[-1]
# Out:
# (0.32927932268381116,
#  0.3103491183593869,
#  0.9214333333333333,
#  0.3436193296670582)

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.3137069344520569 grad_norm: 5.4768581387959685 acc: 0.9
# INFO:root:Test metric acc: 0.6108 loss: 1.5290843850374223

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.20535025000572205 grad_norm: 3.684142511069177 acc: 0.9375
# INFO:root:Test metric acc: 0.6391 loss: 1.3510784006118775

# %%
# INFO:root:train loss epoch: 99 iter: 390 loss:0.2836337089538574 grad_norm: 5.300793375984492 acc: 0.9
# INFO:root:Test metric acc: 0.6114 loss: 1.6074440866708755

# %% [markdown]
# ## overall report

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['_bc-svrg']
# best test acc and config  0.9267666666666666 25 opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.2288937543006341 37706 opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
#
#
# ['_lp-svrg']
# best test acc and config  0.9238333333333334 3 opt_lp-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.24304392104686484 37706 opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['_svrg']
# best test acc and config  0.9268 62 opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.22884702297846707 37706 opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_

# %%
pattern_list = ["_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['_bc-sgd']
# best test acc and config  0.9264333333333333 76 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.244556892697854 37706 opt_bc-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['_lp-sgd']
# best test acc and config  0.9249 87 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.244717666891911 37706 opt_lp-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['_sgd']
# best test acc and config  0.9264 75 opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.24463131569464167 37706 opt_sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_

# %% [markdown]
# ## momentum specific

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["momentum_0.9", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-svrg']
# best test acc and config  0.9267666666666666 25 opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.2288937543006341 37706 opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_bc-svrg']
# best test acc and config  0.9263333333333333 90 opt_bc-svrg_momentum_0.0_lr_0.1_l2_reg_5e-05_
# best train loss and config  0.22982279749178997 37706 opt_bc-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['momentum_0.9', '_lp-svrg']
# best test acc and config  0.9238333333333334 3 opt_lp-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.25902207542895506 2306 opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_lp-svrg']
# best test acc and config  0.9160333333333334 98 opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_
# best train loss and config  0.24304392104686484 37706 opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['momentum_0.9', '_svrg']
# best test acc and config  0.9268 62 opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.22884702297846707 37706 opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_svrg']
# best test acc and config  0.9263 90 opt_svrg_momentum_0.0_lr_0.1_l2_reg_5e-05_
# best train loss and config  0.22981220017109263 37706 opt_svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_

# %%
pattern_list = ["momentum_0.9", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_bc-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_lp-sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.9", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)

pattern_list = ["momentum_0.0", "_sgd"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-sgd']
# best test acc and config  0.9264333333333333 76 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.248766091285097 37706 opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_bc-sgd']
# best test acc and config  0.9257333333333332 99 opt_bc-sgd_momentum_0.0_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.244556892697854 37706 opt_bc-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['momentum_0.9', '_lp-sgd']
# best test acc and config  0.9249 87 opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.25272307629058194 37706 opt_lp-sgd_momentum_0.9_lr_0.05_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_lp-sgd']
# best test acc and config  0.9248 99 opt_lp-sgd_momentum_0.0_lr_0.1_l2_reg_5e-05_
# best train loss and config  0.244717666891911 37706 opt_lp-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_
#
#
# ['momentum_0.9', '_sgd']
# best test acc and config  0.9264 75 opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
# best train loss and config  0.24880714960370823 37706 opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_
#
#
# ['momentum_0.0', '_sgd']
# best test acc and config  0.9257333333333332 99 opt_sgd_momentum_0.0_lr_0.05_l2_reg_1e-05_
# best train loss and config  0.24463131569464167 37706 opt_sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_

# %% [markdown]
# # plot each specific results according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.1_l2_reg_5e-05_",
                       "opt_svrg_momentum_0.0_lr_0.1_l2_reg_5e-05_",
                       "opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.0_lr_0.1_l2_reg_5e-05_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
#     plt.ylim([0.55, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.semilogy(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
#     plt.figure()
#     for pattern, label in zip(pattern_list, label_list):
#         train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")
#         train_loss = running_mean(train_loss, N=1000)
#         plt.semilogy(train_loss, label=label)
#     plt.legend()
#     # plt.ylim([0.55, None])
#     plt.xlabel("iters")
#     plt.ylabel("grad_norm")
#     plt.title("grad norm")
#     plt.grid()
#     plt.show()

# %% [markdown]
# # plot by the best sgd setting according to best accuracy

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.05_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.05_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.0_lr_0.05_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.0_lr_0.05_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.0_lr_0.05_l2_reg_1e-05_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.9_lr_0.01_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.9_lr_0.01_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_1e-05_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.90, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.semilogy(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
#     plt.figure()
#     for pattern, label in zip(pattern_list, label_list):
#         train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")
#         train_loss = running_mean(train_loss, N=1000)
#         plt.semilogy(train_loss, label=label)
#     plt.legend()
#     # plt.ylim([0.55, None])
#     plt.xlabel("iters")
#     plt.ylabel("grad_norm")
#     plt.title("grad norm")
#     plt.grid()
#     plt.show()

# %% [markdown]
# # plot each specific results according to train loss

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_17/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_bc-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.9_lr_0.1_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_bc-sgd_momentum_0.9_lr_0.01_l2_reg_1e-05_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg", "bc-sgd"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
#         if mom == "0.9":
#             print("test results ", pattern, test_acc)
    plt.legend()
    plt.ylim([0.85, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.semilogy(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
#     plt.figure()
#     for pattern, label in zip(pattern_list, label_list):
#         print(pattern)
# #         if "_bc-svrg" in pattern:
# #             continue
#         train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")
#         train_loss = running_mean(train_loss, N=1000)
#         print(label, train_loss[:20], train_loss[-20:])
        
        
#         plt.semilogy(train_loss[:3000], label=label)
#     plt.legend()
#     # plt.ylim([0.55, None])
#     plt.xlabel("iters")
#     plt.ylabel("grad_norm")
#     plt.title("grad norm")
#     plt.grid()
#     plt.show()

# %% [markdown]
# # plot by the best sgd setting

# %%
# top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/logreg_hyper_sweep_2018_nov_13/"
for mom in ["0.0", "0.9"]:
    if mom == "0.0":
        pattern_list = ["opt_sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.0_lr_0.5_l2_reg_1e-05_"]
    else:
        pattern_list = ["opt_sgd_momentum_0.9_lr_0.05_l2_reg_1e-05_", 
                       "opt_lp-sgd_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_lp-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_",
                       "opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_1e-05_"]
    label_list = ["sgd", "lp-sgd", "svrg", "lp-svrg", "bc-svrg"]
    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        test_acc = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="test_acc")
        plt.plot(test_acc, label=label)
    plt.legend()
    plt.ylim([0.85, None])
    plt.xlabel("epoch")
    plt.ylabel("test accuracy")
    plt.title("test acc mom " + mom)
    plt.grid()
    plt.show()

    plt.figure()
    for pattern, label in zip(pattern_list, label_list):
        train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="train_loss")
        train_loss = running_mean(train_loss, N=1000)
        plt.semilogy(train_loss, label=label)
    plt.legend()
    # plt.ylim([0.55, None])
    plt.xlabel("iters")
    plt.ylabel("training loss")
    plt.title("training loss mom " + mom)
    plt.grid()
    plt.show()
    
#     plt.figure()
#     for pattern, label in zip(pattern_list, label_list):
#         train_loss = get_ave_metric(pattern, top_directory, seed_list=[1,2,3], metric="grad_norm")
#         train_loss = running_mean(train_loss, N=1000)
#         plt.semilogy(train_loss, label=label)
#     plt.legend()
#     # plt.ylim([0.55, None])
#     plt.xlabel("iters")
#     plt.ylabel("grad_norm")
#     plt.title("grad norm")
#     plt.grid()
#     plt.show()

# %%
from res_processing_utils import *

# %%
def get_config_with_best_train_loss(top_directory, pattern_list, seed_list=[1, 2, 3]):
        best_train_loss = np.finfo(dtype=np.float64).max
        best_config = ""
        best_loss_epoch_id = 0
        for pattern in pattern_list:
                ave_loss = None
                try:
                    for seed in seed_list:
                            print(pattern, seed)
                            dir = pattern + "seed_" + str(seed)
                            if not os.path.exists(top_directory + "/" + dir + "/run.log"):
                                    print(top_directory + "/" + dir + "/run.log missing!" )
                                    continue
                            loss = get_train_loss(top_directory + "/" + dir + "/run.log")
                            if len(loss) == 0:
                                    print(top_directory + "/" + dir + "/run.log has 0 train loss record" )
                                    continue
                            if ave_loss is None:
                                     ave_loss = np.array(loss)
                            else:
                                     ave_loss += np.array(loss)
                    ave_loss /= len(seed_list)
                    ave_loss = running_mean(ave_loss, N=1000)
                        
                    print(np.min(ave_loss))
                    
                    if np.min(ave_loss) <  best_train_loss:
                            best_train_loss = np.min(ave_loss)
                            best_config = pattern
                            best_loss_epoch_id = np.argmin(ave_loss)
                except:
                        continue
        print("best train loss and config ", best_train_loss, best_loss_epoch_id, best_config)

# %%
top_directory = "/dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13/"
all_directories = get_immediate_subdirectories(top_directory)
all_directories = get_subdirectories_patterns_without_seed(all_directories)

pattern_list = ["momentum_0.9", "_bc-svrg"]
print("\n")
print(pattern_list)
dir_list = filter_directory_names(all_directories, pattern_list)
get_config_with_best_test_acc(top_directory, dir_list)
get_config_with_best_train_loss(top_directory, dir_list)
# Out:
# ['momentum_0.9', '_bc-svrg']
# /dfs/scratch0/zjian/floating_halp/exp_res/lenet_hyper_sweep_2018_nov_13//opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_seed_3/run.log has 0 test accuracy record
# best test acc and config  0.6463 51 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.05_l2_reg_0.0005_ 3
# 1.4589212239583351
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.0001_l2_reg_0.0005_ 3
# 1.3799029947915697
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.5_l2_reg_0.0005_ 3
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.0005_l2_reg_0.0005_ 3
# 0.8122133789062136
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.005_l2_reg_0.0005_ 3
# 0.5985524902343805
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.01_l2_reg_0.0005_ 3
# 0.7517674153645713
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_ 3
# 0.5838754882812209
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 1
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 2
# opt_bc-svrg_momentum_0.9_lr_0.1_l2_reg_0.0005_ 3
# nan
# best train loss and config  0.5838754882812209 36577 opt_bc-svrg_momentum_0.9_lr_0.001_l2_reg_0.0005_
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
